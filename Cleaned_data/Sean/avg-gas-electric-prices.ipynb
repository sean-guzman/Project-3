# %% [markdown]
# # Gas Prices (1992-2022) Dollars per Gallon vs  Electric Prices (2001-2022) Cents per Kilowatt Hour

# %% [markdown]
# https://www.eia.gov/petroleum/
# https://www.eia.gov/electricity/

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import pandas as pd
from datetime import date
import requests
from pprint import pprint

# %%
gas_data = []
electric_data = []

# %%
gas_url = 'https://api.eia.gov/v2/petroleum/pri/gnd/data/?frequency=annual&data[0]=value&facets[series][]=EMM_EPMR_PTE_NUS_DPG&sort[0][column]=period&sort[0][direction]=asc&offset=0&length=5000&api_key='
electric_url = 'https://api.eia.gov/v2/electricity/retail-sales/data/?frequency=annual&data[0]=price&facets[sectorid][]=RES&sort[0][column]=period&sort[0][direction]=asc&offset=0&length=5000&api_key='

api_key='889pPjQxMmDS2Rdd97hnfpsnaiOiLhUYrUk4cyug'

full_gas_url = f"{gas_url}{api_key}"
full_electric_url = f"{electric_url}{api_key}"

# %%
gas_response = requests.get(full_gas_url).json()
electric_response = requests.get(full_electric_url).json()

pprint(electric_response)
# Out:
# {'apiVersion': '2.1.4',
#  'request': {'command': '/v2/electricity/retail-sales/data/',
#              'params': {'api_key': '889pPjQxMmDS2Rdd97hnfpsnaiOiLhUYrUk4cyug',
#                         'data': ['price'],
#                         'facets': {'sectorid': ['RES']},
#                         'frequency': 'annual',
#                         'length': 5000,
#                         'offset': 0,
#                         'sort': [{'column': 'period', 'direction': 'asc'}]}},
#  'response': {'data': [{'period': 2001,
#                         'price': 7.27,
#                         'price-units': 'cents per kilowatthour',
#                         'sectorName': 'residential',
#                         'sectorid': 'RES',
#                         'stateDescription': 'Oklahoma',
#                         'stateid': 'OK'},
#                        {'period': 2001,
#                         'price': 8.58,
#                         'price-units': 'cents per kilowatthour',
# ...

# %%
gas_json = gas_response['response']['data']

# %%
for i in gas_json:

    gas_data.append({"Year": i['period'], 
                     "Gas Value": i['value']})

# %%
gas_data
# Out:
# [{'Year': 1990, 'Gas Value': None},
#  {'Year': 1991, 'Gas Value': None},
#  {'Year': 1992, 'Gas Value': 1.087},
#  {'Year': 1993, 'Gas Value': 1.067},
#  {'Year': 1994, 'Gas Value': 1.075},
#  {'Year': 1995, 'Gas Value': 1.111},
#  {'Year': 1996, 'Gas Value': 1.199},
#  {'Year': 1997, 'Gas Value': 1.199},
#  {'Year': 1998, 'Gas Value': 1.03},
#  {'Year': 1999, 'Gas Value': 1.136},
#  {'Year': 2000, 'Gas Value': 1.484},
#  {'Year': 2001, 'Gas Value': 1.42},
#  {'Year': 2002, 'Gas Value': 1.345},
#  {'Year': 2003, 'Gas Value': 1.561},
#  {'Year': 2004, 'Gas Value': 1.852},
#  {'Year': 2005, 'Gas Value': 2.27},
#  {'Year': 2006, 'Gas Value': 2.572},
#  {'Year': 2007, 'Gas Value': 2.796},
#  {'Year': 2008, 'Gas Value': 3.246},
#  {'Year': 2009, 'Gas Value': 2.353},
#  {'Year': 2010, 'Gas Value': 2.782},
#  {'Year': 2011, 'Gas Value': 3.521},
#  {'Year': 2012, 'Gas Value': 3.618},
#  {'Year': 2013, 'Gas Value': 3.505},
#  {'Year': 2014, 'Gas Value': 3.358},
# ...

# %%
electric_json = electric_response['response']['data']

# %%
for i in electric_json:
    
    if i['stateDescription'] == 'U.S. Total':
        
         electric_data.append({"Year": i['period'],
                               "Electric Value": i['price']})

# %%
electric_data
# Out:
# [{'Year': 2001, 'Electric Value': 8.58},
#  {'Year': 2002, 'Electric Value': 8.44},
#  {'Year': 2003, 'Electric Value': 8.72},
#  {'Year': 2004, 'Electric Value': 8.95},
#  {'Year': 2005, 'Electric Value': 9.45},
#  {'Year': 2006, 'Electric Value': 10.4},
#  {'Year': 2007, 'Electric Value': 10.65},
#  {'Year': 2008, 'Electric Value': 11.26},
#  {'Year': 2009, 'Electric Value': 11.51},
#  {'Year': 2010, 'Electric Value': 11.54},
#  {'Year': 2011, 'Electric Value': 11.72},
#  {'Year': 2012, 'Electric Value': 11.88},
#  {'Year': 2013, 'Electric Value': 12.13},
#  {'Year': 2014, 'Electric Value': 12.52},
#  {'Year': 2015, 'Electric Value': 12.65},
#  {'Year': 2016, 'Electric Value': 12.55},
#  {'Year': 2017, 'Electric Value': 12.89},
#  {'Year': 2018, 'Electric Value': 12.87},
#  {'Year': 2019, 'Electric Value': 13.01},
#  {'Year': 2020, 'Electric Value': 13.15},
#  {'Year': 2021, 'Electric Value': 13.66},
#  {'Year': 2022, 'Electric Value': 15.12}]

# %%
gas_df = pd.DataFrame.from_dict(gas_data)
gas_df
# Out:
#     Year  Gas Value
# 0   1990        NaN
# 1   1991        NaN
# 2   1992      1.087
# 3   1993      1.067
# 4   1994      1.075
# 5   1995      1.111
# 6   1996      1.199
# 7   1997      1.199
# 8   1998      1.030
# 9   1999      1.136
# 10  2000      1.484
# 11  2001      1.420
# 12  2002      1.345
# 13  2003      1.561
# 14  2004      1.852
# 15  2005      2.270
# 16  2006      2.572
# 17  2007      2.796
# 18  2008      3.246
# 19  2009      2.353
# 20  2010      2.782
# 21  2011      3.521
# 22  2012      3.618
# 23  2013      3.505
# 24  2014      3.358
# 25  2015      2.429
# 26  2016      2.143
# 27  2017      2.415
# 28  2018      2.719
# 29  2019      2.604
# 30  2020      2.168
# 31  2021      3.008
# 32  2022      3.951

# %%
electric_df = pd.DataFrame.from_dict(electric_data)
electric_df['Electric Value'] = electric_df['Electric Value']/100
electric_df
# Out:
#     Year  Electric Value
# 0   2001          0.0858
# 1   2002          0.0844
# 2   2003          0.0872
# 3   2004          0.0895
# 4   2005          0.0945
# 5   2006          0.1040
# 6   2007          0.1065
# 7   2008          0.1126
# 8   2009          0.1151
# 9   2010          0.1154
# 10  2011          0.1172
# 11  2012          0.1188
# 12  2013          0.1213
# 13  2014          0.1252
# 14  2015          0.1265
# 15  2016          0.1255
# 16  2017          0.1289
# 17  2018          0.1287
# 18  2019          0.1301
# 19  2020          0.1315
# 20  2021          0.1366
# 21  2022          0.1512

# %%
merged_df = pd.merge(gas_df, electric_df, on ='Year')
merged_df
# Out:
#     Year  Gas Value  Electric Value
# 0   2001      1.420          0.0858
# 1   2002      1.345          0.0844
# 2   2003      1.561          0.0872
# 3   2004      1.852          0.0895
# 4   2005      2.270          0.0945
# 5   2006      2.572          0.1040
# 6   2007      2.796          0.1065
# 7   2008      3.246          0.1126
# 8   2009      2.353          0.1151
# 9   2010      2.782          0.1154
# 10  2011      3.521          0.1172
# 11  2012      3.618          0.1188
# 12  2013      3.505          0.1213
# 13  2014      3.358          0.1252
# 14  2015      2.429          0.1265
# 15  2016      2.143          0.1255
# 16  2017      2.415          0.1289
# 17  2018      2.719          0.1287
# 18  2019      2.604          0.1301
# 19  2020      2.168          0.1315
# 20  2021      3.008          0.1366
# 21  2022      3.951          0.1512

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://seanguzman:Rutgers123!@atlascluster.hbnzjsz.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['mydatabase']
collection = db['avg-gas-electric-prices']
merged_df.reset_index(inplace=True)
data_dict = merged_df.to_dict("records")
# Insert collection
collection.insert_many(data_dict)
